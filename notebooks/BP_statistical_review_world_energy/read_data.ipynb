# %% [markdown]
# ### References
# 1. https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html
# 1. https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy/downloads.html
# 1. https://www.bp.com/content/dam/bp/business-sites/en/global/corporate/xlsx/energy-economics/statistical-review/bp-stats-review-2019-all-data.xlsx

# %%
#import os
import pandas as pd
#import numpy as np
#import matplotlib.pyplot as plt
#import matplotlib.dates as mdates
#import seaborn as sns
#pd.set_option('display.max_rows', 30) 
import tables
import warnings
#warnings.filterwarnings('ignore')
warnings.simplefilter('ignore', tables.NaturalNameWarning) # suppress spammy PyTables warnings

# %%
#xl_file = "bp-stats-review-2019-all-data.xlsx"
#xl_sheet = 'Oil Production - Tonnes'
h5_file = "bp-stats-review-2019.hdf5"
h5_path = "/oil_production"

# %%
#save_df_hdf5 = False
#if os.path.isfile(h5_file):
#    df = pd.read_hdf(h5_file, key=h5_path)
#elif os.path.isfile(xl_file):
#    df = pd.read_excel(xl_file, xl_sheet, header=2, index_col=0, skipfooter=9, keep_default_na=False)
#    save_df_hdf5 = True
df = pd.read_hdf(h5_file, key=h5_path)
df.head(10)
# Out:
#                            1965        1966        1967        1968  \
# Canada                43.874178   48.212154   52.701140   57.119336
# Mexico                18.053894   18.489542   20.463761   21.900666
# US                   427.694442  454.538861  484.221630  502.880332
# Total North America  489.622514  521.240557  557.386531  581.900334
# Argentina             13.764759   14.643966   15.962276   17.487586
# Brazil                 5.041586    6.155685    7.747254    8.513247
# Colombia              10.654546   10.443867   10.075181    9.257762
# Ecuador                0.428781    0.375184    0.321586    0.268722
# Peru                   3.394165    3.394165    3.811905    3.979430
# Trinidad & Tobago      6.671460    7.562912    8.850564    9.485210
#
#                            1969        1970        1971        1972  \
# Canada                62.218043   70.067889   75.163773   86.713147
# Mexico                22.965009   24.179007   24.107319   25.097617
# ...

# %%
df.loc["Denmark"]
# Out:
# 1965          NaN
# 1966          NaN
# 1967          NaN
# 1968          NaN
# 1969          NaN
# 1970          NaN
# 1971          NaN
# 1972     0.097730
# 1973     0.146195
# 1974     0.097463
# 1975     0.146195
# 1976     0.195461
# 1977     0.487316
# 1978     0.389853
# 1979     0.389853
# 1980     0.293191
# 1981     0.730975
# 1982     1.656876
# 1983     2.095461
# 1984     2.296662
# 1985     2.923899
# 1986     3.606142
# 1987     4.532043
# 1988     4.691055
# 1989     5.457944
# 1990     5.896529
# 1991     6.919893
# 1992     7.671829
# 1993     8.186916
# 1994     9.015354
# 1995     9.064085
# 1996    10.163952
# 1997    11.208278
# 1998    11.598131
# 1999    14.570761
# 2000    17.738051
# 2001    16.958611
# 2002    18.079439
# 2003    17.933244
# 2004    19.057410
# 2005    18.516830
# 2006    16.838660
# 2007    15.168849
# 2008    14.035467
# 2009    12.902931
# 2010    12.156576
# 2011    10.940620
# 2012     9.979991
# 2013     8.682906
# 2014     8.130409
# ...
